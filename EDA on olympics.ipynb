# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns




df=pd.read_csv("medal.csv",na_values=['Missing',' '])
print(df.head())
df.describe()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver
#             Edition
# count  29216.000000
# mean    1967.713171
# std       32.406293
# min     1896.000000
# 25%     1948.000000
# 50%     1976.000000
# 75%     1996.000000
# max     2008.000000

# %%
np.where(pd.isnull(df))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
df.rename(columns={'Edition': 'Year', 'Event_gender': 'Sex'}, inplace=True)
df
# Out:
#           City  Year      Sport       Discipline               Athlete  NOC  \
# 0       Athens  1896   Aquatics         Swimming         HAJOS, Alfred  HUN
# 1       Athens  1896   Aquatics         Swimming      HERSCHMANN, Otto  AUT
# 2       Athens  1896   Aquatics         Swimming     DRIVAS, Dimitrios  GRE
# 3       Athens  1896   Aquatics         Swimming    MALOKINIS, Ioannis  GRE
# 4       Athens  1896   Aquatics         Swimming    CHASAPIS, Spiridon  GRE
# ...        ...   ...        ...              ...                   ...  ...
# 29211  Beijing  2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko  GER
# 29212  Beijing  2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas  LTU
# 29213  Beijing  2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri  ARM
# 29214  Beijing  2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain  CUB
# 29215  Beijing  2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan  RUS
#
#       Gender                       Event Sex   Medal
# ...

# %%
#df=df.astype(float)
#df.plot(x='Year', y='Medal')
df.dtypes
# Out:
# City          object
# Year           int64
# Sport         object
# Discipline    object
# Athlete       object
# NOC           object
# Gender        object
# Event         object
# Sex           object
# Medal         object
# dtype: object

# %%
# No of city
print("Cities in Dataset:",df.City.unique(),'\n\n',len(df['City'].unique()),'\n\n')



# no of sports
print("Sports in Dataset:",df['Sport'].unique(),'\n\n',len(df['Sport'].unique()),'\n\n')
# Out:
# Cities in Dataset: ['Athens' 'Paris' 'St Louis' 'London' 'Stockholm' 'Antwerp' 'Amsterdam'
#  'Los Angeles' 'Berlin' 'Helsinki' 'Melbourne / Stockholm' 'Rome' 'Tokyo'
#  'Mexico' 'Munich' 'Montreal' 'Moscow' 'Seoul' 'Barcelona' 'Atlanta'
#  'Sydney' 'Beijing']
#
#  22
#
#
# Sports in Dataset: ['Aquatics' 'Athletics' 'Cycling' 'Fencing' 'Gymnastics' 'Shooting'
#  'Tennis' 'Weightlifting' 'Wrestling' 'Archery' 'Basque Pelota' 'Cricket'
#  'Croquet' 'Equestrian' 'Football' 'Golf' 'Polo' 'Rowing' 'Rugby'
#  'Sailing' 'Tug of War' 'Boxing' 'Lacrosse' 'Roque' 'Hockey'
#  'Jeu de paume' 'Rackets' 'Skating' 'Water Motorsports'
#  'Modern Pentathlon' 'Ice Hockey' 'Basketball' 'Canoe / Kayak' 'Handball'
#  'Judo' 'Volleyball' 'Table Tennis' 'Badminton' 'Baseball' 'Softball'
#  'Taekwondo' 'Triathlon']
#
#  42

# %%
df_gender=df['Gender'].value_counts()
df_gender.head()
# Out:
# Men      21721
# Women     7495
# Name: Gender, dtype: int64

# %%
data_gold=df[np.array(df['Medal']=="Gold")]
data_gold
# Out:
#           City  Year      Sport       Discipline              Athlete  NOC  \
# 0       Athens  1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 3       Athens  1896   Aquatics         Swimming   MALOKINIS, Ioannis  GRE
# 6       Athens  1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 9       Athens  1896   Aquatics         Swimming        NEUMANN, Paul  AUT
# 13      Athens  1896  Athletics        Athletics        BURKE, Thomas  USA
# ...        ...   ...        ...              ...                  ...  ...
# 29199  Beijing  2008  Wrestling  Wrestling Gre-R       GUENOT, Steeve  FRA
# 29203  Beijing  2008  Wrestling  Wrestling Gre-R  KVIRKELIA, Manuchar  GEO
# 29206  Beijing  2008  Wrestling  Wrestling Gre-R     MINGUZZI, Andrea  ITA
# 29210  Beijing  2008  Wrestling  Wrestling Gre-R   KHUSHTOV, Aslanbek  RUS
# 29214  Beijing  2008  Wrestling  Wrestling Gre-R        LOPEZ, Mijain  CUB
#
#       Gender                       Event Sex Medal
# ...

# %%
data_silver=df[np.array(df['Medal']=="Silver")]
data_silver
# Out:
#           City  Year      Sport       Discipline             Athlete  NOC  \
# 1       Athens  1896   Aquatics         Swimming    HERSCHMANN, Otto  AUT
# 4       Athens  1896   Aquatics         Swimming  CHASAPIS, Spiridon  GRE
# 7       Athens  1896   Aquatics         Swimming    ANDREOU, Joannis  GRE
# 10      Athens  1896   Aquatics         Swimming   PEPANOS, Antonios  GRE
# 14      Athens  1896  Athletics        Athletics      HOFMANN, Fritz  GER
# ...        ...   ...        ...              ...                 ...  ...
# 29200  Beijing  2008  Wrestling  Wrestling Gre-R  BEGALIEV, Kanatbek  KGZ
# 29204  Beijing  2008  Wrestling  Wrestling Gre-R    CHANG, Yongxiang  CHN
# 29207  Beijing  2008  Wrestling  Wrestling Gre-R       FODOR, Zoltan  HUN
# 29211  Beijing  2008  Wrestling  Wrestling Gre-R      ENGLICH, Mirko  GER
# 29215  Beijing  2008  Wrestling  Wrestling Gre-R      BAROEV, Khasan  RUS
#
#       Gender                       Event Sex   Medal
# ...

# %%
data_brnz=df[np.array(df['Medal']=="Bronze")]
data_brnz
# Out:
#           City  Year      Sport       Discipline                Athlete  NOC  \
# 2       Athens  1896   Aquatics         Swimming      DRIVAS, Dimitrios  GRE
# 5       Athens  1896   Aquatics         Swimming  CHOROPHAS, Efstathios  GRE
# 8       Athens  1896   Aquatics         Swimming  CHOROPHAS, Efstathios  GRE
# 11      Athens  1896  Athletics        Athletics          LANE, Francis  USA
# 12      Athens  1896  Athletics        Athletics       SZOKOLYI, Alajos  HUN
# ...        ...   ...        ...              ...                    ...  ...
# 29205  Beijing  2008  Wrestling  Wrestling Gre-R          AVLUCA, Nazmi  TUR
# 29208  Beijing  2008  Wrestling  Wrestling Gre-R        MAMBETOV, Asset  KAZ
# 29209  Beijing  2008  Wrestling  Wrestling Gre-R          WHEELER, Adam  USA
# 29212  Beijing  2008  Wrestling  Wrestling Gre-R   MIZGAITIS, Mindaugas  LTU
# 29213  Beijing  2008  Wrestling  Wrestling Gre-R        PATRIKEEV, Yuri  ARM
#
# ...

# %%
def find(year,sport,Medal="Gold"):
    data_find=df[(df['Year']==year) & (df['Sport']==sport) & (df['Medal']==Medal)]
    return data_find
find(2000,"Wrestling")
# Out:
#          City  Year      Sport       Discipline                    Athlete  \
# 25129  Sydney  2000  Wrestling  Wrestling Free.          ABDULLAYEV, Namig
# 25132  Sydney  2000  Wrestling  Wrestling Free.             DABIR, Alireza
# 25135  Sydney  2000  Wrestling  Wrestling Free.         OUMAKHANOV, Mourad
# 25138  Sydney  2000  Wrestling  Wrestling Free.              IGALI, Daniel
# 25141  Sydney  2000  Wrestling  Wrestling Free.              SLAY, Brandon
# 25144  Sydney  2000  Wrestling  Wrestling Free.              SAITIEV, Adam
# 25147  Sydney  2000  Wrestling  Wrestling Free.      MOURTASALIYEV, Saghid
# 25150  Sydney  2000  Wrestling  Wrestling Free.         MOUSSOULBES, David
# 25153  Sydney  2000  Wrestling  Wrestling Gre-R               SIM, Kwon-Ho
# 25156  Sydney  2000  Wrestling  Wrestling Gre-R            NAZARIAN, Armen
# 25159  Sydney  2000  Wrestling  Wrestling Gre-R      SAMURGASHEV, Varteres
# ...

# %%
df['Gender'].value_counts().plot(kind='barh', figsize=(8, 6))

# %%
df.groupby(['Year','Gender']).size().unstack().plot(figsize=(15,10),kind='bar',stacked=True)
plt.show()

# %%
print(df.groupby(['City','Medal']).size().reset_index(name='Total_medals'))
ax=df.groupby(['City','Medal']).size().unstack().plot(figsize=(17,10),kind='bar',stacked=True,title='Cities with all medals',color=('chocolate','gold','silver'))

ax.set_ylabel("Total Medals",fontsize=18)
ax.set_xlabel("Cities",fontsize=18)
plt.show()
# Out:
#          City   Medal  Total_medals
# 0   Amsterdam  Bronze           242
# 1   Amsterdam    Gold           229
# 2   Amsterdam  Silver           239
# 3     Antwerp  Bronze           355
# 4     Antwerp    Gold           497
# ..        ...     ...           ...
# 61     Sydney    Gold           663
# 62     Sydney  Silver           667
# 63      Tokyo  Bronze           343
# 64      Tokyo    Gold           330
# 65      Tokyo  Silver           337
#
# [66 rows x 3 columns]

# %%
ax=df.groupby(['City','Gender']).size().unstack().plot(figsize=(15,10),kind='barh',stacked=True,title='Men/Women ratio')
ax.set_xlabel("Total participants",fontsize=18)
ax.set_ylabel("Cities",fontsize=18)
plt.show()
